# %% [markdown]
# # 1. step: Prerequisites

# %% [markdown]
# The following steps are required for the scripts to run properly.
#
# Please run them by pressing <b>SHIFT + ENTER</b>.

# %% [markdown]
# ## 1.1. Import Libraries

# %% [markdown]
# Scripts use the following libraries.

# %%
import numpy as np
import pandas as pd
#import matplotlib as mp
#import matplotlib.pyplot as plt
#from matplotlib.patches import Polygon
import os
import re
import math
from datetime import datetime
from zipfile import ZipFile

# %% [markdown]
# ## 1.2. Set constans (manually)

# %% [markdown]
# Set the dir variable which is the directory where CSV files are located.
#
# If you would like to use different directory for unzip file from drive, please set dir_raw variable as well.

# %%
filename = "data0421"
triplet_file = 'triplet_type.csv'
csv_filename = "all_20230421.csv"

# %%
zip_directory = filename + "/"
print(zip_directory)
zip_file = filename + ".zip"
print(zip_file)
# Out:
# data0421/
# data0421.zip

# %% [markdown]
# # Unzip

# %% [markdown]
# <b>uzip function</b> extracts the file.
#
# <b>Input:</b>
# - zip_file (type: string): the path to the file
# - dir_raw (type: string): where the zip file is unzipped

# %%
def unzip(zip_file,zip_directory):
    with ZipFile(zip_file, 'r') as zip:
        # printing all the contents of the zip file
        zip.printdir()

        # extracting all the files
        print('Extracting all the files now...')
        zip.extractall(zip_directory)
        print('Done!')

# %%
#unzip(zip_file,zip_directory)

# %% [markdown]
# Check the directory and remove the files!

# %%
dir_list = list(filter(lambda name: ".csv" in name, os.listdir(zip_directory)))

# %%
dir_list
# Out:
# ['1011.csv',
#  '2027_NeMO-asrt_mixed_fish_v4_2023-04-01_10h37.49.391.csv',
#  '1028_NeMO-asrt_mixed_fish_v4_2023-04-05_17h24.51.297.csv',
#  '1029_NeMO-asrt_mixed_fish_v4_2023-04-05_18h32.40.656.csv',
#  '1031_NeMO-asrt_mixed_fish_v4_2023-04-12_18h15.50.164 (1).csv',
#  '2018_NeMO-asrt_mixed_fish_v4_2023-02-20_15h57.55.766.csv',
#  '2014_asrt_mixed_fish_v2_2023-01-28_10h44.21.487.csv',
#  '2013_asrt_mixed_fish_v2_2023-01-30_12h20.28.788.csv']

# %% [markdown]
# # 2. step: Data cleaning

# %% [markdown]
# ## 2.1 Read and concatenate data file and triplet file

# %%
df_triplet_type = pd.read_csv(triplet_file,sep=';',engine='python')
#df_triplet_type = df_triplet_type.dropna()
#df_triplet_type = df_triplet_type.reset_index(drop=True)
#print(df_triplet_type.to_string())
print(df_triplet_type)
# Out:
#       block  position  type  trial_type
# 0         1      -365     0          50
# 1         1      -117     0          50
# 2         1       127     0          50
# 3         1       369     0          50
# 4         1       369     0          50
# ...     ...       ...   ...         ...
# 1695     20       127     1          11
# 1696     20      -117     2          12
# 1697     20       369     1          11
# 1698     20       369     2          20
# 1699     20      -365     1          11
#
# [1700 rows x 4 columns]

# %%
def dataclean(filename):
    print("-------------------------")
    print("Data cleaning started...")
    print
    # filter columns
    df = pd.read_csv(zip_directory + filename)
    df = df[["stimulus.thisIndex","mouse.time","mouse.clicked_name","position_x","mouse.leftButton"]]
    df = df.dropna()
    df = df.reset_index(drop=True)
    
    # print(df)
    
    # adding triplets to the files
    result = pd.concat([df, df_triplet_type],axis=1)
    result = result.dropna()
    
    #print(result[["stimulus.thisIndex","block","position_x","position","trial_type"]].to_string())
    print("Column names: ", df.columns.values)
    print("Number of rows: ", len(result))
    
    print("Data cleaning finished...")
    
    return result

# %%
def accuracy(result):
    print("-------------------------")
    print("Accuracy cleaning started...")
    
    result['mouse.leftButton_len'] = result['mouse.leftButton'].str.len()
    
    indexMoreTrial = result[(result['mouse.leftButton_len'] > 3)].index
    
    print("Number of rows: ", len(result))
    print("Number of deleted rows: ", len(indexMoreTrial))
          
    result.drop(indexMoreTrial , inplace=True)

    indexTrials = result[(result['trial_type'] == 50)].index
    result.drop(indexTrials , inplace=True)
    result = result.reset_index(drop=True)
    
    print("Remaining rows: ", len(result))
    
    print("Accuracy cleaning finished.")
    
    return result

# %%
def RTtoFloat(result):
    print("-------------------------")
    print("RT type conversation started...")
    result['mouse.time'] = result['mouse.time'].str[1:-1]
    result['mouse.time'] = result['mouse.time'].astype(float)
    
    print("Remaining rows: ", result['mouse.time'].dtype)
    
    print("RT type conversation finished.")
    
    return result

# %%
def elim_outliars(result):
    print("-------------------------")
    print("Eliminating outliars started...")
    dataset = result['mouse.time']
    q1,q3 = np.percentile(dataset,[25,75])
    print("Q1 = ", q1)
    print("Q3 = ", q3)
    
    iqr = q3-q1
    print("IQR = ", iqr)
    
    #find higher and lower fence
    lower_fence = q1 - (1.5 * iqr)
    higher_fence = q3 + (1.5 * iqr)
    print("Lower fence: ", lower_fence)
    print("Higher fence: ", higher_fence)
    
    indexOutliers = result[(result["mouse.time"] > higher_fence) | (result["mouse.time"] < lower_fence)].index
    #indexOutliers = result[(result["mouse.time"] > higher_fence)].index
    print("Number of rows: ", len(result))
    print("Number of deleted rows: ", len(indexOutliers))
    
    result.drop(indexOutliers , inplace=True)

    result = result.reset_index(drop=True)
    
    print("Remaining rows: ", len(result))
    print("Eliminating outliars finished.")
    
    return result

# %% [markdown]
# # 3. step: Analysis

# %%
def medianRT(result,triplet):
    print("-------------------------")
    print("Median RT analysis started...")
    print("Selected triplet types: ", triplet)
    
    # H – High Probabilty Triplets: 12
    # L – Low Probabilty Triplets: 20
    # P – Pattern Triplets: 11
    # HP – High and Pattern: 12 and 11
    

    arr_median = []
    
    max_block_value = result["block"].max()
    
    print("Number of blocks: ", max_block_value)
    
    for i in range(1,max_block_value+1): 
        print("Block number: ", i)
        
        result_block=result.loc[result["block"] == i]
        
        if triplet == "H":
            result_triplets = result_block.loc[result_block["trial_type"] == 12]
        elif triplet == "L":
            result_triplets = result_block.loc[result_block["trial_type"] == 20]
        elif triplet == "P":
            result_triplets = result_block.loc[result_block["trial_type"] == 11]
        elif triplet == "HP":
            result_triplets = result_block.loc[(result_block["trial_type"] == 12) | 
                                               (result_block["trial_type"] == 11)]
        else:
            print("Error: Triplet type is not valid.")
    
        median = result_triplets["mouse.time"].median()
        print("Median: ", median)
        
    
        arr_median.append(median)
        
        print("Array of medians by blocks: ", arr_median)
    
    print("Median RT analysis finished.")
    print("-------------------------")
        
    return arr_median

# %% [markdown]
# # 4.step: Data table creation

# %%
dir_list_len = len(dir_list)
print(dir_list_len)
# Out:
# 8

# %%
df_randHigh = pd.DataFrame()
df_randLow = pd.DataFrame()
df_pattern = pd.DataFrame()
df_high = pd.DataFrame()
arr_participant = []

df = pd.DataFrame()

for file in dir_list:
    print(file)
    result = dataclean(file)
    result = accuracy(result)
    result = RTtoFloat(result)
    result = elim_outliars(result)
    
    participant = file[:4] 
    arr_participant.append(participant)
    
    
    arr_randHigh = medianRT(result,"H")
    new_row = pd.Series(arr_randHigh)
    df_randHigh = df_randHigh.append(new_row, ignore_index=True)
    
    arr_randLow = medianRT(result,"L")
    new_row = pd.Series(arr_randLow)
    df_randLow = df_randLow.append(new_row, ignore_index=True)
    
    arr_pattern = medianRT(result,"P")
    new_row = pd.Series(arr_pattern)
    df_pattern = df_pattern.append(new_row, ignore_index=True)
    
    arr_high = medianRT(result,"HP")
    new_row = pd.Series(arr_high)
    df_high = df_high.append(new_row, ignore_index=True)
    
    print(" ")
    
participant_series = pd.Series(arr_participant)

# rename the Series column to 'participant'
participant_series = participant_series.rename('participant')
    
df = pd.concat([participant_series, df_participant, df_randHigh, df_randLow, df_pattern, df_high], axis=1)

print(df)
    
#df.to_csv("all.csv")
# Out:
# 1011.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  935
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  935
# Number of deleted rows:  72
# Remaining rows:  790
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.7775000000002166
# Q3 =  1.01274999999994
# IQR =  0.2352499999997235
# Lower fence:  0.4246250000006313
# Higher fence:  1.3656249999995254
# Number of rows:  790
# Number of deleted rows:  106
# Remaining rows:  684
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  11
# Block number:  1
# Median:  0.9525000000000006
# Array of medians by blocks:  [0.9525000000000006]
# Block number:  2
# Median:  0.8790000000000191
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191]
# Block number:  3
# Median:  0.8930000000000291
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291]
# Block number:  4
# Median:  0.8569999999999709
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709]
# Block number:  5
# Median:  0.8249999999999318
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318]
# Block number:  6
# Median:  0.9070000000000391
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391]
# Block number:  7
# Median:  0.9580000000000837
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391, 0.9580000000000837]
# Block number:  8
# Median:  0.9244999999999663
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391, 0.9580000000000837, 0.9244999999999663]
# Block number:  9
# Median:  0.8259999999999081
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391, 0.9580000000000837, 0.9244999999999663, 0.8259999999999081]
# Block number:  10
# Median:  0.7824999999999136
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391, 0.9580000000000837, 0.9244999999999663, 0.8259999999999081, 0.7824999999999136]
# Block number:  11
# Median:  0.8450000000000273
# Array of medians by blocks:  [0.9525000000000006, 0.8790000000000191, 0.8930000000000291, 0.8569999999999709, 0.8249999999999318, 0.9070000000000391, 0.9580000000000837, 0.9244999999999663, 0.8259999999999081, 0.7824999999999136, 0.8450000000000273]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  11
# Block number:  1
# Median:  0.9449999999999932
# Array of medians by blocks:  [0.9449999999999932]
# Block number:  2
# Median:  0.8289999999999509
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509]
# Block number:  3
# Median:  0.8505000000000109
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109]
# Block number:  4
# Median:  0.8670000000000186
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186]
# Block number:  5
# Median:  0.833500000000015
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015]
# Block number:  6
# Median:  0.7664999999999509
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509]
# Block number:  7
# Median:  0.9239999999999782
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509, 0.9239999999999782]
# Block number:  8
# Median:  0.8730000000000473
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509, 0.9239999999999782, 0.8730000000000473]
# Block number:  9
# Median:  0.8759999999999764
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509, 0.9239999999999782, 0.8730000000000473, 0.8759999999999764]
# Block number:  10
# Median:  0.8450000000000273
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509, 0.9239999999999782, 0.8730000000000473, 0.8759999999999764, 0.8450000000000273]
# Block number:  11
# Median:  0.74249999999995
# Array of medians by blocks:  [0.9449999999999932, 0.8289999999999509, 0.8505000000000109, 0.8670000000000186, 0.833500000000015, 0.7664999999999509, 0.9239999999999782, 0.8730000000000473, 0.8759999999999764, 0.8450000000000273, 0.74249999999995]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  11
# Block number:  1
# Median:  0.9250000000000114
# Array of medians by blocks:  [0.9250000000000114]
# Block number:  2
# Median:  0.8790000000000191
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191]
# Block number:  3
# Median:  0.8770000000000095
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095]
# Block number:  4
# Median:  0.8419999999999845
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845]
# Block number:  5
# Median:  0.8994999999999891
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891]
# Block number:  6
# Median:  0.8994999999999891
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891]
# Block number:  7
# Median:  0.8619999999998527
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891, 0.8619999999998527]
# Block number:  8
# Median:  0.8740000000000236
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891, 0.8619999999998527, 0.8740000000000236]
# Block number:  9
# Median:  0.7845000000000937
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891, 0.8619999999998527, 0.8740000000000236, 0.7845000000000937]
# Block number:  10
# Median:  0.8250000000000455
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891, 0.8619999999998527, 0.8740000000000236, 0.7845000000000937, 0.8250000000000455]
# Block number:  11
# Median:  0.8154999999999291
# Array of medians by blocks:  [0.9250000000000114, 0.8790000000000191, 0.8770000000000095, 0.8419999999999845, 0.8994999999999891, 0.8994999999999891, 0.8619999999998527, 0.8740000000000236, 0.7845000000000937, 0.8250000000000455, 0.8154999999999291]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  11
# Block number:  1
# Median:  0.9270000000000209
# Array of medians by blocks:  [0.9270000000000209]
# Block number:  2
# Median:  0.8790000000000191
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191]
# Block number:  3
# Median:  0.8845000000000312
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312]
# Block number:  4
# Median:  0.8419999999999845
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845]
# Block number:  5
# Median:  0.8509999999999991
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991]
# Block number:  6
# Median:  0.9060000000000628
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628]
# Block number:  7
# Median:  0.8724999999998317
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628, 0.8724999999998317]
# Block number:  8
# Median:  0.8740000000000236
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628, 0.8724999999998317, 0.8740000000000236]
# Block number:  9
# Median:  0.8004999999999427
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628, 0.8724999999998317, 0.8740000000000236, 0.8004999999999427]
# Block number:  10
# Median:  0.8089999999999691
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628, 0.8724999999998317, 0.8740000000000236, 0.8004999999999427, 0.8089999999999691]
# Block number:  11
# Median:  0.8250000000000455
# Array of medians by blocks:  [0.9270000000000209, 0.8790000000000191, 0.8845000000000312, 0.8419999999999845, 0.8509999999999991, 0.9060000000000628, 0.8724999999998317, 0.8740000000000236, 0.8004999999999427, 0.8089999999999691, 0.8250000000000455]
# Median RT analysis finished.
# -------------------------
#
# 2027_NeMO-asrt_mixed_fish_v4_2023-04-01_10h37.49.391.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  170
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  170
# Number of deleted rows:  15
# Remaining rows:  142
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  1.4667499999999336
# Q3 =  2.645749999999964
# IQR =  1.1790000000000305
# Lower fence:  -0.3017500000001121
# Higher fence:  4.41425000000001
# Number of rows:  142
# Number of deleted rows:  15
# Remaining rows:  127
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  2
# Block number:  1
# Median:  1.9035000000000082
# Array of medians by blocks:  [1.9035000000000082]
# Block number:  2
# Median:  1.711999999999989
# Array of medians by blocks:  [1.9035000000000082, 1.711999999999989]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  2
# Block number:  1
# Median:  2.393000000000029
# Array of medians by blocks:  [2.393000000000029]
# Block number:  2
# Median:  1.4290000000000873
# Array of medians by blocks:  [2.393000000000029, 1.4290000000000873]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  2
# Block number:  1
# Median:  2.02800000000002
# Array of medians by blocks:  [2.02800000000002]
# Block number:  2
# Median:  1.5610000000001492
# Array of medians by blocks:  [2.02800000000002, 1.5610000000001492]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  2
# Block number:  1
# Median:  2.02800000000002
# Array of medians by blocks:  [2.02800000000002]
# Block number:  2
# Median:  1.5785000000000764
# Array of medians by blocks:  [2.02800000000002, 1.5785000000000764]
# Median RT analysis finished.
# -------------------------
#
# 1028_NeMO-asrt_mixed_fish_v4_2023-04-05_17h24.51.297.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  850
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  850
# Number of deleted rows:  86
# Remaining rows:  695
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.8089999999997417
# Q3 =  1.3174999999998818
# IQR =  0.5085000000001401
# Lower fence:  0.04624999999953161
# Higher fence:  2.080250000000092
# Number of rows:  695
# Number of deleted rows:  87
# Remaining rows:  608
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  10
# Block number:  1
# Median:  1.2164999999999964
# Array of medians by blocks:  [1.2164999999999964]
# Block number:  2
# Median:  0.9259999999999309
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309]
# Block number:  3
# Median:  1.1250000000002274
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274]
# Block number:  4
# Median:  0.9084999999997763
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763]
# Block number:  5
# Median:  0.8914999999997235
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235]
# Block number:  6
# Median:  0.7919999999999163
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235, 0.7919999999999163]
# Block number:  7
# Median:  0.8835000000001401
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235, 0.7919999999999163, 0.8835000000001401]
# Block number:  8
# Median:  1.0929999999998472
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235, 0.7919999999999163, 0.8835000000001401, 1.0929999999998472]
# Block number:  9
# Median:  0.9580000000000837
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235, 0.7919999999999163, 0.8835000000001401, 1.0929999999998472, 0.9580000000000837]
# Block number:  10
# Median:  0.8020000000001346
# Array of medians by blocks:  [1.2164999999999964, 0.9259999999999309, 1.1250000000002274, 0.9084999999997763, 0.8914999999997235, 0.7919999999999163, 0.8835000000001401, 1.0929999999998472, 0.9580000000000837, 0.8020000000001346]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  10
# Block number:  1
# Median:  1.3260000000000218
# Array of medians by blocks:  [1.3260000000000218]
# Block number:  2
# Median:  1.0115000000000691
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691]
# Block number:  3
# Median:  0.9579999999996289
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289]
# Block number:  4
# Median:  0.8919999999998254
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254]
# Block number:  5
# Median:  0.8719999999998436
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436]
# Block number:  6
# Median:  0.9415000000001328
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436, 0.9415000000001328]
# Block number:  7
# Median:  0.8835000000001401
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436, 0.9415000000001328, 0.8835000000001401]
# Block number:  8
# Median:  0.8795000000000073
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436, 0.9415000000001328, 0.8835000000001401, 0.8795000000000073]
# Block number:  9
# Median:  0.88149999999996
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436, 0.9415000000001328, 0.8835000000001401, 0.8795000000000073, 0.88149999999996]
# Block number:  10
# Median:  0.875
# Array of medians by blocks:  [1.3260000000000218, 1.0115000000000691, 0.9579999999996289, 0.8919999999998254, 0.8719999999998436, 0.9415000000001328, 0.8835000000001401, 0.8795000000000073, 0.88149999999996, 0.875]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  10
# Block number:  1
# Median:  1.3334999999999582
# Array of medians by blocks:  [1.3334999999999582]
# Block number:  2
# Median:  1.00850000000014
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014]
# Block number:  3
# Median:  0.9855000000000018
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018]
# Block number:  4
# Median:  0.8989999999998872
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872]
# Block number:  5
# Median:  0.88799999999992
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992]
# Block number:  6
# Median:  0.8460000000000036
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992, 0.8460000000000036]
# Block number:  7
# Median:  0.9100000000000819
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992, 0.8460000000000036, 0.9100000000000819]
# Block number:  8
# Median:  0.8409999999998945
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992, 0.8460000000000036, 0.9100000000000819, 0.8409999999998945]
# Block number:  9
# Median:  0.7934999999997672
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992, 0.8460000000000036, 0.9100000000000819, 0.8409999999998945, 0.7934999999997672]
# Block number:  10
# Median:  0.8344999999999345
# Array of medians by blocks:  [1.3334999999999582, 1.00850000000014, 0.9855000000000018, 0.8989999999998872, 0.88799999999992, 0.8460000000000036, 0.9100000000000819, 0.8409999999998945, 0.7934999999997672, 0.8344999999999345]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  10
# Block number:  1
# Median:  1.2579999999998108
# Array of medians by blocks:  [1.2579999999998108]
# Block number:  2
# Median:  0.9919999999997344
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344]
# Block number:  3
# Median:  1.000999999999749
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749]
# Block number:  4
# Median:  0.8989999999998872
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872]
# Block number:  5
# Median:  0.88799999999992
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992]
# Block number:  6
# Median:  0.8439999999998236
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992, 0.8439999999998236]
# Block number:  7
# Median:  0.9100000000000819
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992, 0.8439999999998236, 0.9100000000000819]
# Block number:  8
# Median:  0.8409999999998945
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992, 0.8439999999998236, 0.9100000000000819, 0.8409999999998945]
# Block number:  9
# Median:  0.8434999999999491
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992, 0.8439999999998236, 0.9100000000000819, 0.8409999999998945, 0.8434999999999491]
# Block number:  10
# Median:  0.8260000000000218
# Array of medians by blocks:  [1.2579999999998108, 0.9919999999997344, 1.000999999999749, 0.8989999999998872, 0.88799999999992, 0.8439999999998236, 0.9100000000000819, 0.8409999999998945, 0.8434999999999491, 0.8260000000000218]
# Median RT analysis finished.
# -------------------------
#
# 1029_NeMO-asrt_mixed_fish_v4_2023-04-05_18h32.40.656.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  340
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  340
# Number of deleted rows:  10
# Remaining rows:  303
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.9089999999999918
# Q3 =  1.2084999999999582
# IQR =  0.29949999999996635
# Lower fence:  0.4597500000000423
# Higher fence:  1.6577499999999077
# Number of rows:  303
# Number of deleted rows:  33
# Remaining rows:  270
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  4
# Block number:  1
# Median:  0.95900000000006
# Array of medians by blocks:  [0.95900000000006]
# Block number:  2
# Median:  1.0160000000000764
# Array of medians by blocks:  [0.95900000000006, 1.0160000000000764]
# Block number:  3
# Median:  1.0420000000001437
# Array of medians by blocks:  [0.95900000000006, 1.0160000000000764, 1.0420000000001437]
# Block number:  4
# Median:  0.9590000000002874
# Array of medians by blocks:  [0.95900000000006, 1.0160000000000764, 1.0420000000001437, 0.9590000000002874]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  4
# Block number:  1
# Median:  1.0014999999999645
# Array of medians by blocks:  [1.0014999999999645]
# Block number:  2
# Median:  1.0425000000000182
# Array of medians by blocks:  [1.0014999999999645, 1.0425000000000182]
# Block number:  3
# Median:  0.95049999999992
# Array of medians by blocks:  [1.0014999999999645, 1.0425000000000182, 0.95049999999992]
# Block number:  4
# Median:  1.043999999999869
# Array of medians by blocks:  [1.0014999999999645, 1.0425000000000182, 0.95049999999992, 1.043999999999869]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  4
# Block number:  1
# Median:  1.0209999999999582
# Array of medians by blocks:  [1.0209999999999582]
# Block number:  2
# Median:  1.0909999999998945
# Array of medians by blocks:  [1.0209999999999582, 1.0909999999998945]
# Block number:  3
# Median:  0.9790000000000418
# Array of medians by blocks:  [1.0209999999999582, 1.0909999999998945, 0.9790000000000418]
# Block number:  4
# Median:  1.0235000000000127
# Array of medians by blocks:  [1.0209999999999582, 1.0909999999998945, 0.9790000000000418, 1.0235000000000127]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  4
# Block number:  1
# Median:  1.0090000000000146
# Array of medians by blocks:  [1.0090000000000146]
# Block number:  2
# Median:  1.0260000000000673
# Array of medians by blocks:  [1.0090000000000146, 1.0260000000000673]
# Block number:  3
# Median:  0.9919999999999618
# Array of medians by blocks:  [1.0090000000000146, 1.0260000000000673, 0.9919999999999618]
# Block number:  4
# Median:  0.9920000000001892
# Array of medians by blocks:  [1.0090000000000146, 1.0260000000000673, 0.9919999999999618, 0.9920000000001892]
# Median RT analysis finished.
# -------------------------
#
# 1031_NeMO-asrt_mixed_fish_v4_2023-04-12_18h15.50.164 (1).csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  1020
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  1020
# Number of deleted rows:  58
# Remaining rows:  879
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.7830000000000155
# Q3 =  1.0669999999998936
# IQR =  0.2839999999998781
# Lower fence:  0.35700000000019827
# Higher fence:  1.4929999999997108
# Number of rows:  879
# Number of deleted rows:  60
# Remaining rows:  819
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  12
# Block number:  1
# Median:  0.8474999999999966
# Array of medians by blocks:  [0.8474999999999966]
# Block number:  2
# Median:  0.8279999999999745
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745]
# Block number:  3
# Median:  1.0130000000000337
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337]
# Block number:  4
# Median:  0.9329999999999927
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927]
# Block number:  5
# Median:  0.9669999999999845
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845]
# Block number:  6
# Median:  0.9610000000000127
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127]
# Block number:  7
# Median:  0.9474999999999909
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909]
# Block number:  8
# Median:  0.8994999999999891
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909, 0.8994999999999891]
# Block number:  9
# Median:  0.8700000000000045
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909, 0.8994999999999891, 0.8700000000000045]
# Block number:  10
# Median:  0.8460000000000036
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909, 0.8994999999999891, 0.8700000000000045, 0.8460000000000036]
# Block number:  11
# Median:  0.8829999999998108
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909, 0.8994999999999891, 0.8700000000000045, 0.8460000000000036, 0.8829999999998108]
# Block number:  12
# Median:  0.9289999999996326
# Array of medians by blocks:  [0.8474999999999966, 0.8279999999999745, 1.0130000000000337, 0.9329999999999927, 0.9669999999999845, 0.9610000000000127, 0.9474999999999909, 0.8994999999999891, 0.8700000000000045, 0.8460000000000036, 0.8829999999998108, 0.9289999999996326]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  12
# Block number:  1
# Median:  0.9329999999999927
# Array of medians by blocks:  [0.9329999999999927]
# Block number:  2
# Median:  0.8940000000000055
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055]
# Block number:  3
# Median:  0.8290000000000646
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646]
# Block number:  4
# Median:  0.9180000000000064
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064]
# Block number:  5
# Median:  0.8209999999999695
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695]
# Block number:  6
# Median:  0.9009999999999536
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536]
# Block number:  7
# Median:  0.86200000000008
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008]
# Block number:  8
# Median:  0.7449999999998909
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008, 0.7449999999998909]
# Block number:  9
# Median:  0.9740000000000464
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008, 0.7449999999998909, 0.9740000000000464]
# Block number:  10
# Median:  0.9449999999999363
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008, 0.7449999999998909, 0.9740000000000464, 0.9449999999999363]
# Block number:  11
# Median:  0.9145000000000891
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008, 0.7449999999998909, 0.9740000000000464, 0.9449999999999363, 0.9145000000000891]
# Block number:  12
# Median:  0.8960000000001855
# Array of medians by blocks:  [0.9329999999999927, 0.8940000000000055, 0.8290000000000646, 0.9180000000000064, 0.8209999999999695, 0.9009999999999536, 0.86200000000008, 0.7449999999998909, 0.9740000000000464, 0.9449999999999363, 0.9145000000000891, 0.8960000000001855]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  12
# Block number:  1
# Median:  0.9535000000000053
# Array of medians by blocks:  [0.9535000000000053]
# Block number:  2
# Median:  0.978999999999985
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985]
# Block number:  3
# Median:  0.9800000000000182
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182]
# Block number:  4
# Median:  0.9130000000000109
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109]
# Block number:  5
# Median:  0.9289999999999736
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736]
# Block number:  6
# Median:  0.9189999999999827
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827]
# Block number:  7
# Median:  0.8460000000000036
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036]
# Block number:  8
# Median:  0.7950000000000728
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036, 0.7950000000000728]
# Block number:  9
# Median:  0.8449999999997999
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036, 0.7950000000000728, 0.8449999999997999]
# Block number:  10
# Median:  0.8279999999999745
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036, 0.7950000000000728, 0.8449999999997999, 0.8279999999999745]
# Block number:  11
# Median:  0.8760000000002037
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036, 0.7950000000000728, 0.8449999999997999, 0.8279999999999745, 0.8760000000002037]
# Block number:  12
# Median:  0.8524999999999636
# Array of medians by blocks:  [0.9535000000000053, 0.978999999999985, 0.9800000000000182, 0.9130000000000109, 0.9289999999999736, 0.9189999999999827, 0.8460000000000036, 0.7950000000000728, 0.8449999999997999, 0.8279999999999745, 0.8760000000002037, 0.8524999999999636]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  12
# Block number:  1
# Median:  0.9290000000000163
# Array of medians by blocks:  [0.9290000000000163]
# Block number:  2
# Median:  0.9519999999999982
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982]
# Block number:  3
# Median:  0.9800000000000182
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182]
# Block number:  4
# Median:  0.9214999999999804
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804]
# Block number:  5
# Median:  0.9349999999999454
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454]
# Block number:  6
# Median:  0.9270000000000209
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209]
# Block number:  7
# Median:  0.8510000000001128
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128]
# Block number:  8
# Median:  0.8140000000000782
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128, 0.8140000000000782]
# Block number:  9
# Median:  0.8650000000000091
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128, 0.8140000000000782, 0.8650000000000091]
# Block number:  10
# Median:  0.8289999999999509
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128, 0.8140000000000782, 0.8650000000000091, 0.8289999999999509]
# Block number:  11
# Median:  0.8780000000001564
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128, 0.8140000000000782, 0.8650000000000091, 0.8289999999999509, 0.8780000000001564]
# Block number:  12
# Median:  0.8609999999998763
# Array of medians by blocks:  [0.9290000000000163, 0.9519999999999982, 0.9800000000000182, 0.9214999999999804, 0.9349999999999454, 0.9270000000000209, 0.8510000000001128, 0.8140000000000782, 0.8650000000000091, 0.8289999999999509, 0.8780000000001564, 0.8609999999998763]
# Median RT analysis finished.
# -------------------------
#
# 2018_NeMO-asrt_mixed_fish_v4_2023-02-20_15h57.55.766.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  340
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  340
# Number of deleted rows:  144
# Remaining rows:  176
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.8417500000000757
# Q3 =  1.3122500000000628
# IQR =  0.47049999999998704
# Lower fence:  0.13600000000009516
# Higher fence:  2.0180000000000433
# Number of rows:  176
# Number of deleted rows:  24
# Remaining rows:  152
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  4
# Block number:  1
# Median:  1.117999999999995
# Array of medians by blocks:  [1.117999999999995]
# Block number:  2
# Median:  1.1675000000000182
# Array of medians by blocks:  [1.117999999999995, 1.1675000000000182]
# Block number:  3
# Median:  1.1170000000000186
# Array of medians by blocks:  [1.117999999999995, 1.1675000000000182, 1.1170000000000186]
# Block number:  4
# Median:  0.8410000000000082
# Array of medians by blocks:  [1.117999999999995, 1.1675000000000182, 1.1170000000000186, 0.8410000000000082]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  4
# Block number:  1
# Median:  1.0655000000000143
# Array of medians by blocks:  [1.0655000000000143]
# Block number:  2
# Median:  0.9604999999999677
# Array of medians by blocks:  [1.0655000000000143, 0.9604999999999677]
# Block number:  3
# Median:  1.1754999999999995
# Array of medians by blocks:  [1.0655000000000143, 0.9604999999999677, 1.1754999999999995]
# Block number:  4
# Median:  0.8550000000000182
# Array of medians by blocks:  [1.0655000000000143, 0.9604999999999677, 1.1754999999999995, 0.8550000000000182]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  4
# Block number:  1
# Median:  1.0970000000000368
# Array of medians by blocks:  [1.0970000000000368]
# Block number:  2
# Median:  1.0579999999999927
# Array of medians by blocks:  [1.0970000000000368, 1.0579999999999927]
# Block number:  3
# Median:  1.059000000000026
# Array of medians by blocks:  [1.0970000000000368, 1.0579999999999927, 1.059000000000026]
# Block number:  4
# Median:  0.9080000000000155
# Array of medians by blocks:  [1.0970000000000368, 1.0579999999999927, 1.059000000000026, 0.9080000000000155]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  4
# Block number:  1
# Median:  1.1010000000000275
# Array of medians by blocks:  [1.1010000000000275]
# Block number:  2
# Median:  1.0649999999999409
# Array of medians by blocks:  [1.1010000000000275, 1.0649999999999409]
# Block number:  3
# Median:  1.059000000000026
# Array of medians by blocks:  [1.1010000000000275, 1.0649999999999409, 1.059000000000026]
# Block number:  4
# Median:  0.8745000000000118
# Array of medians by blocks:  [1.1010000000000275, 1.0649999999999409, 1.059000000000026, 0.8745000000000118]
# Median RT analysis finished.
# -------------------------
#
# 2014_asrt_mixed_fish_v2_2023-01-28_10h44.21.487.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  340
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  340
# Number of deleted rows:  43
# Remaining rows:  272
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  0.8919999999999959
# Q3 =  1.4089999999999776
# IQR =  0.5169999999999817
# Lower fence:  0.11650000000002336
# Higher fence:  2.18449999999995
# Number of rows:  272
# Number of deleted rows:  26
# Remaining rows:  246
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  4
# Block number:  1
# Median:  1.2239999999999895
# Array of medians by blocks:  [1.2239999999999895]
# Block number:  2
# Median:  1.025000000000034
# Array of medians by blocks:  [1.2239999999999895, 1.025000000000034]
# Block number:  3
# Median:  0.9750000000000227
# Array of medians by blocks:  [1.2239999999999895, 1.025000000000034, 0.9750000000000227]
# Block number:  4
# Median:  0.9080000000000155
# Array of medians by blocks:  [1.2239999999999895, 1.025000000000034, 0.9750000000000227, 0.9080000000000155]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  4
# Block number:  1
# Median:  1.3259999999999934
# Array of medians by blocks:  [1.3259999999999934]
# Block number:  2
# Median:  0.8919999999999959
# Array of medians by blocks:  [1.3259999999999934, 0.8919999999999959]
# Block number:  3
# Median:  1.0749999999999318
# Array of medians by blocks:  [1.3259999999999934, 0.8919999999999959, 1.0749999999999318]
# Block number:  4
# Median:  0.9759999999999991
# Array of medians by blocks:  [1.3259999999999934, 0.8919999999999959, 1.0749999999999318, 0.9759999999999991]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  4
# Block number:  1
# Median:  1.163499999999999
# Array of medians by blocks:  [1.163499999999999]
# Block number:  2
# Median:  1.009999999999991
# Array of medians by blocks:  [1.163499999999999, 1.009999999999991]
# Block number:  3
# Median:  0.9915000000000305
# Array of medians by blocks:  [1.163499999999999, 1.009999999999991, 0.9915000000000305]
# Block number:  4
# Median:  0.9329999999999927
# Array of medians by blocks:  [1.163499999999999, 1.009999999999991, 0.9915000000000305, 0.9329999999999927]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  4
# Block number:  1
# Median:  1.1730000000000018
# Array of medians by blocks:  [1.1730000000000018]
# Block number:  2
# Median:  1.0175000000000125
# Array of medians by blocks:  [1.1730000000000018, 1.0175000000000125]
# Block number:  3
# Median:  0.9909999999999854
# Array of medians by blocks:  [1.1730000000000018, 1.0175000000000125, 0.9909999999999854]
# Block number:  4
# Median:  0.9239999999999782
# Array of medians by blocks:  [1.1730000000000018, 1.0175000000000125, 0.9909999999999854, 0.9239999999999782]
# Median RT analysis finished.
# -------------------------
#
# 2013_asrt_mixed_fish_v2_2023-01-30_12h20.28.788.csv
# -------------------------
# Data cleaning started...
# Column names:  ['stimulus.thisIndex' 'mouse.time' 'mouse.clicked_name' 'position_x'
#  'mouse.leftButton']
# Number of rows:  170
# Data cleaning finished...
# -------------------------
# Accuracy cleaning started...
# Number of rows:  170
# Number of deleted rows:  32
# Remaining rows:  125
# Accuracy cleaning finished.
# -------------------------
# RT type conversation started...
# Remaining rows:  float64
# RT type conversation finished.
# -------------------------
# Eliminating outliars started...
# Q1 =  1.02800000000002
# Q3 =  1.8909999999999911
# IQR =  0.8629999999999711
# Lower fence:  -0.2664999999999367
# Higher fence:  3.185499999999948
# Number of rows:  125
# Number of deleted rows:  15
# Remaining rows:  110
# Eliminating outliars finished.
# -------------------------
# Median RT analysis started...
# Selected triplet types:  H
# Number of blocks:  2
# Block number:  1
# Median:  1.3449999999999847
# Array of medians by blocks:  [1.3449999999999847]
# Block number:  2
# Median:  1.1239999999999668
# Array of medians by blocks:  [1.3449999999999847, 1.1239999999999668]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  L
# Number of blocks:  2
# Block number:  1
# Median:  1.2090000000000032
# Array of medians by blocks:  [1.2090000000000032]
# Block number:  2
# Median:  1.0249999999999773
# Array of medians by blocks:  [1.2090000000000032, 1.0249999999999773]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  P
# Number of blocks:  2
# Block number:  1
# Median:  1.3585000000000065
# Array of medians by blocks:  [1.3585000000000065]
# Block number:  2
# Median:  1.2195000000000107
# Array of medians by blocks:  [1.3585000000000065, 1.2195000000000107]
# Median RT analysis finished.
# -------------------------
# -------------------------
# Median RT analysis started...
# Selected triplet types:  HP
# Number of blocks:  2
# Block number:  1
# Median:  1.3585000000000065
# Array of medians by blocks:  [1.3585000000000065]
# Block number:  2
# Median:  1.1720000000000255
# Array of medians by blocks:  [1.3585000000000065, 1.1720000000000255]
# Median RT analysis finished.
# -------------------------
#
#   participant       0       1      2       3       4      5       6       7  \
# 0        1011  0.9525  0.8790  0.893  0.8570  0.8250  0.907  0.9580  0.9245
# 1        2027  1.9035  1.7120    NaN     NaN     NaN    NaN     NaN     NaN
# 2        1028  1.2165  0.9260  1.125  0.9085  0.8915  0.792  0.8835  1.0930
# 3        1029  0.9590  1.0160  1.042  0.9590     NaN    NaN     NaN     NaN
# 4        1031  0.8475  0.8280  1.013  0.9330  0.9670  0.961  0.9475  0.8995
# 5        2018  1.1180  1.1675  1.117  0.8410     NaN    NaN     NaN     NaN
# 6        2014  1.2240  1.0250  0.975  0.9080     NaN    NaN     NaN     NaN
# 7        2013  1.3450  1.1240    NaN     NaN     NaN    NaN     NaN     NaN
#
#        8  ...       2       3      4      5       6      7       8      9  \
# 0  0.826  ...  0.8845  0.8420  0.851  0.906  0.8725  0.874  0.8005  0.809
# 1    NaN  ...     NaN     NaN    NaN    NaN     NaN    NaN     NaN    NaN
# 2  0.958  ...  1.0010  0.8990  0.888  0.844  0.9100  0.841  0.8435  0.826
# 3    NaN  ...  0.9920  0.9920    NaN    NaN     NaN    NaN     NaN    NaN
# 4  0.870  ...  0.9800  0.9215  0.935  0.927  0.8510  0.814  0.8650  0.829
# 5    NaN  ...  1.0590  0.8745    NaN    NaN     NaN    NaN     NaN    NaN
# 6    NaN  ...  0.9910  0.9240    NaN    NaN     NaN    NaN     NaN    NaN
# 7    NaN  ...     NaN     NaN    NaN    NaN     NaN    NaN     NaN    NaN
#
#       10     11
# 0  0.825    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4  0.878  0.861
# 5    NaN    NaN
# 6    NaN    NaN
# 7    NaN    NaN
#
# [8 rows x 49 columns]

# %%
columns = df.columns.tolist()

# create a list to store the new column names
new_columns = []

# initialize the prefix variable to be used for the next set of columns
prefix = ""

# loop through each column name
for col in columns:
    if col == 0:
        # if the column name is 0, change the prefix accordingly
        if prefix == "":
            prefix = "randHigh_"
        elif prefix == "randHigh_":
            prefix = "randLow_"
        elif prefix == "randLow_":
            prefix = "Pattern_"
        elif prefix == "Pattern_":
            prefix = "High_"
    # add the prefix and column number to the new column names list
    new_columns.append(prefix + str(col))

# create an empty dataframe with the new column names
df.columns = new_columns

df = df.fillna(0)

print(df)
# Out:
#   participant  randHigh_0  randHigh_1  randHigh_2  randHigh_3  randHigh_4  \
# 0        1011      0.9525      0.8790       0.893      0.8570      0.8250
# 1        2027      1.9035      1.7120       0.000      0.0000      0.0000
# 2        1028      1.2165      0.9260       1.125      0.9085      0.8915
# 3        1029      0.9590      1.0160       1.042      0.9590      0.0000
# 4        1031      0.8475      0.8280       1.013      0.9330      0.9670
# 5        2018      1.1180      1.1675       1.117      0.8410      0.0000
# 6        2014      1.2240      1.0250       0.975      0.9080      0.0000
# 7        2013      1.3450      1.1240       0.000      0.0000      0.0000
#
#    randHigh_5  randHigh_6  randHigh_7  randHigh_8  ...  High_2  High_3  \
# 0       0.907      0.9580      0.9245       0.826  ...  0.8845  0.8420
# 1       0.000      0.0000      0.0000       0.000  ...  0.0000  0.0000
# 2       0.792      0.8835      1.0930       0.958  ...  1.0010  0.8990
# 3       0.000      0.0000      0.0000       0.000  ...  0.9920  0.9920
# 4       0.961      0.9475      0.8995       0.870  ...  0.9800  0.9215
# 5       0.000      0.0000      0.0000       0.000  ...  1.0590  0.8745
# 6       0.000      0.0000      0.0000       0.000  ...  0.9910  0.9240
# 7       0.000      0.0000      0.0000       0.000  ...  0.0000  0.0000
#
#    High_4  High_5  High_6  High_7  High_8  High_9  High_10  High_11
# 0   0.851   0.906  0.8725   0.874  0.8005   0.809    0.825    0.000
# 1   0.000   0.000  0.0000   0.000  0.0000   0.000    0.000    0.000
# 2   0.888   0.844  0.9100   0.841  0.8435   0.826    0.000    0.000
# 3   0.000   0.000  0.0000   0.000  0.0000   0.000    0.000    0.000
# 4   0.935   0.927  0.8510   0.814  0.8650   0.829    0.878    0.861
# 5   0.000   0.000  0.0000   0.000  0.0000   0.000    0.000    0.000
# 6   0.000   0.000  0.0000   0.000  0.0000   0.000    0.000    0.000
# 7   0.000   0.000  0.0000   0.000  0.0000   0.000    0.000    0.000
#
# [8 rows x 49 columns]

# %%
#df.drop(df.index[0], inplace=True)
#print(df)
#df.drop(df.index[2], inplace=True)
#print(df)
#df.to_csv("all.csv")

# %%
df.to_csv(csv_filename)

# %% [markdown]
# ## Archive

# %%
def statistical_diff(result):
    print("Statistic learning analysis started...")
    arr_exp_stat = []

    arr_randhigh = []
    arr_randlow = []
    
    max_block_value = result["block"].max()
    
    print("Number of blocks: ", max_block_value)
    
    for i in range(1,max_block_value): 
        print("Block number: ", i)
        
        result_block=result.loc[result["block"] == i]
        #print(result_block.shape)
        result_h = result_block.loc[result_block["trial_type"] == 12]
        #print(result_h)
        result_l = result_block.loc[result_block["trial_type"] == 20]
        #print(result_l.shape)

        m_h = result_h["mouse.time"].median()
        print("High Prob Median: ", m_h)
        
        m_l = result_l["mouse.time"].median()
        print("Low Prob Median: ",m_l)
    
        print("Diff Low-High: ", m_l-m_h)
    
        arr_randhigh.append(m_h)
        arr_randlow.append(m_l)

        arr_exp_stat.append(m_l-m_h)
        
        print("Array of diff: ", arr_exp_stat)
             
    df_exp_stat = pd.DataFrame(arr_exp_stat, columns = ["Stat_diff_Low-High"])
    
    print("Statistic learning analysis finished.")
        
    return df_exp_stat

# %%
def sequential_diff(result):
    print("Sequential learning analysis started...")
    arr_exp_stat = []
    arr_exp_seq = []

    arr_pattern = []
    arr_randhigh = []
    
    max_block_value = result["block"].max()
    print("Number of blocks: ", max_block_value)
    
    for i in range(1,max_block_value): 
        print("Block number: ", i)
        
        #print(i)
        result_block=result.loc[result["block"] == i]
        #print(result_block.shape)
        result_p = result_block.loc[result_block["trial_type"] == 11]
        #print(result_p.shape)
        result_h = result_block.loc[result_block["trial_type"] == 12]
        #print(result_h)

        m_p = result_p["mouse.time"].median()
        print("Pattern Median: ", m_p)
        
        #print(result_p[["mouse.time","block","trial_type"]])
        #print(result_p["mouse.time"].median())
        
        m_h = result_h["mouse.time"].median()
        print("High Prob Median: ", m_h)
    
        #print(m_h-m_p)
        print("Diff High-Pattern: ", m_h-m_p)
    
        arr_pattern.append(m_p)
        arr_randhigh.append(m_h)

        arr_exp_seq.append(m_h-m_p)
        print("Array of diff: ", arr_exp_seq)
        
    df_exp_seq = pd.DataFrame(arr_exp_seq, columns = ["Seq_diff_High-Pattern"])
    
    print("Sequential learning analysis finished.")
        
    return df_exp_seq

# %%
def implicit_diff(result):
    print("Implicit learning analysis started...")
    
    arr_imp = []
    #arr_high =[]
    
    max_block_value = result["block"].max()
    print("Number of blocks: ", max_block_value)

    for i in range(1,max_block_value): 
        print("Block number: ", i)
        
        #print(i)
        result_block=result.loc[result["block"] == i]
        #print(result_block.shape)
        #result_p = result_block.loc[result_block["trial_type"] == 11 | ]
        #print(result_p.shape)
        result_h = result_block.loc[(result_block["trial_type"] == 12) | (result_block["trial_type"] == 11)]
        #print(result_h)
        result_l = result_block.loc[result_block["trial_type"] == 20]
        #print(result_l.shape)

        #m_p = result_p["mouse.time"].median()
        #print(result_p[["mouse.time","block","trial_type"]])
        #print(result_p["mouse.time"].median())
        #print(m_p)
        m_hp = result_h["mouse.time"].median()
        print("High-Pattern Median: ", m_h)
        #print(m_h)
        
        m_l = result_l["mouse.time"].median()
        print("Low Median: ", m_l)
        #print(m_l)

        #print(m_l-m_h)
        print("Diff Low-High-Pattern: ", m_l-m_hp)

        #arr_exp_stat.append(m_h-m_p)
        arr_imp.append(m_l-m_hp)
        print("Array of diff: ", arr_imp)
        
        #arr_high.append(m_h)


    #print(arr)
    df_imp = pd.DataFrame(arr_imp, columns = ["Imp_diff_HighPattern-Low"])
    
    print("Implicit learning analysis finished.")
    
    return df_imp
